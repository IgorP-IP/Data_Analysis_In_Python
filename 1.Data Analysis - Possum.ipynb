# %% [markdown]
# ###  16 cells / 1 lessons

# %% [markdown]
# ### Data Analysis In Python. Inroduction. Possum
#
# ### Ссылка для скачивания материалов курса:
#
# ### https://github.com/IgorP-IP/Data_Analysis_In_Python
#
# #### Автор: Приходько Игорь Анатольевич
#
# #### email: aieipidko@gmail.com
#
# ##### г.Санкт-Петербург
#
#
# ![ML and BD-pic.gif](attachment:560d31ca-a863-41c6-a33d-0f52916014fd.gif)

# %% [markdown]
# # 1 lesson
#
# # Lesson topic: Inroduction. Possum

# %% [markdown]
# ### Машинное обучение заключается в извлечении знаний из данных.
#
# Это научная область, находящаяся на пересечении статистики, искусственного интеллекта и компьютерных наук и также известная как
#
# прогнозная аналитика или статистическое обучение.
#
# В последние годы применение методов машинного обучения в повседневной жизни стало обыденным явлением.
#
# Многие современные веб-сайты и устройства используют алгоритмы машинного обучения, начиная с
#
# ● автоматических рекомендаций по просмотру фильмов,
#
# ● заказа еды или покупки продуктов, и заканчивая
#
# ● персонализированными онлайн-радиотрансляциями и
#
# ● распознаванием друзей на фотографиях.
#
# Когда вы видите сложный сайт типа Amazon или Netflix, то весьма вероятно, что каждый раздел сайта содержит несколько моделей машинного обучения.
#
# Сейчас методы машинного обучения используются для решения различных научных задач:
#
# ● исследование звезд,
#
# ● поиск далеких планет,
#
# ● открытие новых частиц,
#
# ● анализ последовательностей ДНК,
#
# ● а также разработка персонализированных методов лечения рака).

# %% [markdown]
# ### Задачи, которые можно решить с помощью машинного обучения
#
# Наиболее успешные алгоритмы машинного обучения – это те, которые
# автоматизируют процессы принятия решений путем обобщения
# известных примеров.
#
# ### ●  Алгоритмы обучения с учителем или контролируемое обучение (supervised learning) - это вид алгоритмов,
# ##### где пользователь предоставляет алгоритму пары объект-ответ, а алгоритм находит способ получения ответа по объекту.
# ##### В частности, алгоритм способен выдать ответ для объекта, которого он никогда не видел раньше, без какой-либо помощи человека.
#
# Примеры задач машинного обучения с учителем:
#
# #####  ► Классификация спама в электронных письмах
#
# #####  ► Определение почтового индекса по рукописным цифрам на конверте
#
# #####  ► Определение доброкачественности опухоли на основе медицинских изображений
#
# #####  ► Обнаружение мошеннической деятельности в сделках по кредитным картам
#
# ### ● Алгоритмы обучения без учителя или неконтролируемого обучения (unsupervised algorithms) –
# ##### это еще один вид алгоритмов, где известны только объекты, а ответов нет.
# ##### Хотя есть много успешных сфер применения этих методов, их, как правило, труднее интерпретировать и оценить.
#
# Примеры задач машинного обучения без учителя:
#
# #####  ► Определение тем в наборе постов
#
# #####  ► Сегментирование клиентов на группы с похожими предпочтениями
#
# #####  ► Обнаружение паттернов аномального поведения на веб-сайте

# %% [markdown]
# Решая задачи машинного обучения с учителем и без, важно
# представить ваши входные данные в формате, понятном компьютеру.
# Часто данные представляют в виде таблицы.
#
# ##### ► В машинном обучении каждый объект или строка называются примером (sample) или точкой данных (data point),
#
# ##### ► а столбцы-свойства, которые описывают эти примеры, называются характеристиками или признаками (features).
#
# Позже в этой курсе мы более детально остановимся на теме
# подготовки данных, которая называется
#
# ##### ► выделение признаков (feature extraction) или
#
# ##### ► конструирование признаков (feature engineering).

# %% [markdown]
# ### Постановка задач и знакомство с данными
#
# Во-первых Вы должны максимально точно сформулировать задачу, которую вы хотите решить.
#
# Далее, Вы должны познакоиться с теми данными, которые есть в Вашем распоряжении.

# %% [markdown]
# ### Почему нужно использовать Python?
#
# Python стал общепринятым языком для многих сфер применения науки о данных (data science).
#
# В Python есть библиотеки для загрузки данных, визуализации, статистических вычислений, обработки естественного языка, обработки изображений и
#
# многого другого.
#
# Одним из основных преимуществ использования Python является возможность напрямую работать с программным кодом с помощью терминала или других
#
# инструментов типа Jupyter Notebook, c которым мы с Вами уже знакомы.

# %% [markdown]
# ### scikit-learn
#
# ### https://scikit-learn.org/
#
# scikit-learn – проект с открытым исходным кодом.
#
# Проект scikit-learn постоянно развивается и совершенствуется, и у него очень активное сообщество пользователей.
#
# Он содержит ряд современных алгоритмов машинного обучения, а также полную документацию по каждому алгоритму.
#
# scikit-learn – очень популярный инструмент и самая известная питоновская библиотека для машинного обучения.

# %% [markdown]
# #### Установка scikit-learn
#
# scikit-learn требует наличия еще двух пакетов Python – NumPy и
# SciPy. Для построения графиков и интерактивной работы необходимо
# также установить matplotlib, Jupyter Notebook.
# Можно установить все требуемые пакеты на Ваш компьюте по отдельности.
# Для этого нужно в командной строке ввести команду:
#
# ##### pip install scikit-learn
#
# Чтобы убедиться, что все установлено, в командной строке нужжно ввести команду:
#
# ##### pip freeze
#
# И убедиться, что в спике установленных пакетов появился пакет scikit-learn.
#
# Установку scikit-learn можно осуществить непосредственно через Jupyter Notebook.
# Для этого в отдельной ячейке нужно ввести
#
# ##### !pip install scikit-learn
#
# И если Ваш ноутбук не вернул Вам исключение (ошибку), то scikit-learn
# установлен на Ваш компьютер благополучно.

# %%
# !pip install scikit-learn

# %% [markdown]
# ### Основные библиотеки и инструменты
#
# ##### Jupyter Notebook
#
# Jupyter Notebook представляет собой интерактивную среду для запуска
# программного кода в браузере. Это отличный инструмент для
# разведочного анализа данных и широко используется специалистами по
# анализу данных.
#
# ##### NumPy
#
# NumPy – это один из основных пакетов для научных вычислений в
# Python. Он содержит функциональные возможности для работы с
# многомерными массивами, высокоуровневыми математическими
# функциями (операции линейной алгебры, преобразование Фурье,
# генератор псевдослучайных чисел).
#
# В scikit-learn массив NumPy – это основная структура данных.
# scikit-learn принимает данные в виде массивов NumPy.

# %% [markdown]
# ##### matplotlib
#
# matplotlib – это основная библиотека для построения научных графиков в Python.
#
# Она включает функции для создания высококачественных
# визуализаций типа линейных диаграмм, гистограмм, диаграмм разброса и т.д.
#
# Визуализация данных и различных аспектов вашего анализа может
# дать вам важную информацию, и мы будем использовать matplotlib для
# всех наших визуализаций.
#
# При работе в Jupyter Notebook, вы можете вывести рисунок прямо в браузере с помощью встроенных команд
#
# %matplotlib notebook и %matplotlib inline.

# %% [markdown]
# ##### pandas
#
# pandas – библиотека Python для обработки и анализа данных.
#
# Она построена на основе структуры данных, называемой DataFrame и
# смоделированной по принципу датафреймов среды статистического
# программирования R.
#
# Проще говоря, DataFrame библиотеки pandas
# представляет собой таблицу, похожую на электронную таблицу Excel.
#
# В отличие от NumPy, который требует, чтобы
# все записи в массиве были одного и того же типа, в pandas каждый
# столбец может иметь отдельный тип (например, целые числа, даты, числа
# с плавающей точкой и строки).

# %% [markdown]
# ### Пример решения задачи машинного обучения.
#
# #### 1.Введение в задачу:
#
# ##### ● Загрузка необходимых библиотек
#
# ##### ● Загрузка датасета
#
# ##### ● ● Подготовка датасета
#
# ##### ● ● Описание задачи:
#
# ##### ● ● ● Задача регрессии
#
# ##### ● ● ● Задача классификации
#
# #### 2.Знакомство с алгоритмом машинного обучения (KNN) и библиотекой sklearn:
#
# ##### ● Имплементация (реализация) алгоритма (KNN)
#
# ##### ● Алгоритм (KNN) при помощи sklearn
#
# #### 3.Описание метрик:
#
# ##### ● для регрессии
#
# #### 4.Переобучение и методы борьбы с ним:
#
# ##### ● Кросс-валидация
#
# ##### ● GridSearchCV
#
# #### 5.Сохранение модели

# %% [markdown]
# #### Реализуем конкретную задачу, на примере dataset possum.csv.
#
# ### 1.Введение в задачу:

# %% [markdown]
# ##### ● Загрузка необходимых библиотек
#
# ###### 1-я строка: удалим более старую версию библиотеки
#
# ###### 2-я строка: установим новую версию библиотеки

# %%
# !pip uninstall -y scikit-learn 
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##### ● Загрузка датасета

# %% [markdown]
# #### В этом примере мы будем работать с данными с kaggle соревнования Possum Regression.
#
# В этой задаче нужно предсказать возраст оппосума по имеющимся в нём данным:
#
# ##### ● Target - age - Возраст
#
# ##### ● case - Номер наблюдения
#
# ##### ● site - Номер участка, на котором был отловлен оппосум
#
# ##### ● Pop - Поселение, либо Vic(Виктория), либо другое (Новый Южный Уэльс или Квинсленд)
#
# ##### ● sex - Пол
#
# ##### ● hdlnth - Длина головы, в мм
#
# ##### ● skullw - Ширина черепа, в мм
#
# ##### ● totlnth - Общая длина, в см
#
# ##### ● taill - Длина хвоста, в см
#
# ##### ● footlnf - Длина стопы
#
# ##### ● earcounch - Длина ушной раковины
#
# ##### ● ere - Расстояние от медиального канта до латерального канта правого глаза
#
# ##### ● chest - Обхват груди, в см
#
# ##### ● belly - Обхват живота, в см

# %% [markdown]
# ![image.png](attachment:74f0e653-fa12-4435-8846-cb8d465d42e3.png)

# %% [markdown]
# #### ● ● Описание задачи
#
# В этом примере мы будем решать задачу регрессии.
#
# ### ► Задача регрессии - это задача прогнозирования количественных переменных, т.е.величин y,
#
# ### которые принадлежат множеству действительных чисел y ∈ R
#
# Друими словами, нам нужно предсказать какую-то непрерывную величину.
#
# Пример задачи регрессии - предсказаие стоимости дома на основании его площади, количества комнат и расположения.
#
# ### ► Задача классификации - это предсказание категориальных переменных (классов)
#
# ### на основе признаков элементов.
#
# Пример задачи классификации - определение вида растения на основании его размеров и формы листьев, здесь соличество видов растения конечно.
#
# ##### Давайте приведём примеры задачи регрессии и задачи классификации на примере датасета про оппосумов,
#
# который мы будем использовать на этом занятии.
#
# Пример задачи классификации - определить жив оппосум или мёрт (оппосумы любят притворяться мёртвыми).
#
# В такой задаче будет всего 2 класса: 0 - оппосум притворился, что мётр,
#
# 1 - действительно оппосум мёртв. Здесь значения чётко детерминированы - нет какго-то промежуточного значения.
#
# Пример здачи регрессии - спрогнозировать возраст оппосума. Здесь мы будем предсказывать непрерывную величину - возраст
#
# (age - это target - целевая переменная). Вот именно эту задачу - прогнозирование возраста оппосума мы и решим.

# %%
# загружаем наши данные в DataFrame 
df = pd.read_csv('possum.csv')
df

# %%
# Для больших наборов данных Jupyter Notebook сокращает количество показываемых данных
# Если Вы хотите посмотреть ИМЕННО ВСЕ ДАННЫЕ, то установите:
pd.set_option('display.max_columns', None) # для колонок
pd.set_option('display.max_rows', None) # Для строк
df

# %% [markdown]
# ### *************************************************************
#
# ### Импорт данных
#
# ##### pd.read_csv('filename')   # позволяет читать файлы CSV (с разделителями запятыми)
#
#                                 # и преобразовывать их в формат Pandas DataFrame
#
# ##### pd.read_excel('filename') # позволяет загружать данные из Excel-файлов в DataFrame
#
# ##### pd.read_sql(query, connection_object) # выполняет указанный SQL-запрос и сохраняет результаты в кадре данных pandas
#
# ##### pd.read_table(filename)   # читает табличные данные из файла или строки в фрейм данных pandas
#
# ##### pd.read_json(json_string) # позволяет считывать данные JSON в фрейм данных Pandas
#
# ##### pd.read_html(url)         # извлекает таблицы из HTML-страницы
#
# ##### pd.read_clipboard()       # создаёт DataFrame из данных, скопированных в буфер обмена
#
# ##### pd.DataFrame(dict)        # DataFrame — это одна из основных структур данных в библиотеке Pandas,
#
#                                 # предназначенная для работы с табличными данными
#
# ### *************************************************************
#
# ### Экспорт данных
#
# ##### df.to_csv(filename)
#
# ##### df.to_excel(filename)
#
# ##### df.to_sql(table_name, connection_object)
#
# ##### df.to_json(filename)
#
# ##### df.to_html(filename)
#
# ##### df.to_clipboard()
#
# ##### File --> Save  and Export Notebook AS --> PDF # сохранить notebook в PDF-файл
#
# ### *************************************************************

# %%
# посмотрит на первые 3 строки нашего dataset
df.head(3)

# %%
# посмотрит на последние 5 строк нашего dataset
df.tail(5)

# %%
# Давайте подумаем: все ли признаки (столбы) нам важны для решения нашей задачи?
# Удаляем неинформативные признаки: case, site, Pop, sex
df = df.drop(columns=['case', 'site', 'Pop', 'sex'])
df.head(3)

# %%
# Проверим, есть ли в нашем dataset пропуски
df.isna().sum()

# %% [markdown]
# Признак age имеет 2 пропуска, признак footlgth имеет 1 пропуск.
#
# Давайте их тоже удалим.

# %%
df.dropna(inplace = True)

# %% [markdown]
# Разделим наш dataset на переменные - массив X - и целевую (target) переменную - y

# %%
X = df.drop(columns=['age']).values
y = df['age'].values

# %% [markdown]
# Разделим наш dataset на trainset и test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle = True, test_size = 0.2, random_state=42)

# %% [markdown]
# ### 2.Знакомство с алгоритмом машинного обучения (KNN) и библиотекой sklearn:

# %% [markdown]
# Теперь мы можем начать строить реальную модель машинного обучения.
#
# В данном примере мы будем использовать классификатор на основе метода k ближайших соседей, который легко интерпретировать.
#
# Построение этой модели заключается лишь в запоминании обучающего набора.
#
# Для того, чтобы сделать прогноз для новой точки данных, алгоритм находит точку в обучающем наборе, которая находится ближе
#
# всего к новой точке.
#
# Затем он присваивает метку, принадлежащую этой точке обучающего набора, новой точке данных.
#
# k в методе k ближайших соседей означает, что вместо того, чтобы использовать лишь ближайшего соседа новой точки данных,
#
# мы в ходе обучения можем рассмотреть любое фиксированное число (k) соседей (например, рассмотреть ближайшие три или пять соседей).
#
# Тогда мы можем сделать прогноз для точки данных, используя класс, которому принадлежит большинство ее соседей.

# %% [markdown]
# ![image.png](attachment:f9b33e61-434c-412e-925a-531a99986f43.png)

# %% [markdown]
# Решая нашу задачу, мы можем пойти по 2-м путям:
#
# #### 1) Мы будем вручную всё делать:
#
# ##### 1 шаг: нужно создать функцию подсчета расстояния между элементами,
#
# ##### 2 шаг: нужно найти ближайших соседей,
#
# ##### 3 шаг: нужно получить предсказание для тестовых данных
#
# Решение этой задачи потребует написания немалого количества кода на языке Python.
#
# То есть это - решаемая задача, но она трудоёмкая. Её сложность будет расти по мере увеличения размера нашего dataset.
#
# #### 2) Мы можем решить эту задачу, используя библиотеку scikit-learn.
#
# #### И это превращает трудоёмкое и длительное решение в короткое решение.

# %% [markdown]
# Замечательная библиотека scikit-learn всё уже реаализовала и обернула всю логику алгоритма KNN (и многих других
#
# алгоритмов, с которыми мы в последствии познакомимся) в питоновские классы!

# %%
# Шаг 1. Создание модели
model = KNeighborsRegressor(n_neighbors = 5)

# Шаг 2. Обучение модели
model.fit(X_train, y_train)

# Шаг 3. Предсказание на тестовых данных
y_pred = model.predict(X_test)

# %%
# Распечатаем предсказанную целевую переменную
y_pred

# %% [markdown]
# ### 3.Метрики

# %% [markdown]
# Отлично мы получили предсказание. Но мы должны быть уверены в качестве предсказаний нашей модели.
#
# Для этого существуют метрики.
#
# ### Метрики - это функции, которые принимают на вход правильные ответы на тестовые данные
#
# ### и ответы модели, и выдают число - меру "хорошести" предсказаний модели.
#
# Метрики для различных задач - разные.
#
# Метрики для задач регрессии: MSE, RMSE, R^2, MAE.
#
# Метрики для задач классификации: Accuracy, Precision, Recall, F1-measure, ROC AUC.

# %% [markdown]
# ### Формулы для вычисления метрик для задач регрессии:
#
# ![image.png](attachment:e79e97d2-817a-46a6-b572-ec373c4f9cd9.png)
#
# ![image.png](attachment:b134d64b-2d39-467e-ab35-f1e3cfd35578.png)
#
# ![image.png](attachment:98a6f1fa-f49e-4eed-8350-69c650c0578e.png)
#
# ![image.png](attachment:b0114c4e-fe98-4880-82a3-14bd8aa3afa8.png)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score, mean_absolute_error

pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

MSE_train = mean_squared_error(y_train, pred_train)
RMSE_train = np.sqrt(MSE_train)
R2_train = r2_score(y_train, pred_train)
MAE_train = mean_absolute_error(y_train, pred_train)

MSE_test = mean_squared_error(y_test, pred_test)
RMSE_test = np.sqrt(MSE_test)
R2_test = r2_score(y_test, pred_test)
MAE_test = mean_absolute_error(y_test, pred_test)

print(f'MSE на обучении {MSE_train:.2f}')
print(f'MSE на тесте {MSE_test:.2f}', end = '\n\n')

print(f'RMSE на обучении {RMSE_train:.2f}')
print(f'RMSE на тесте {RMSE_test:.2f}', end = '\n\n')

print(f'R^2 на обучении {R2_train:.2f}')
print(f'R^2 на тесте {R2_test:.2f}', end = '\n\n')

print(f'MAE на обучении {MAE_train:.2f}')
print(f'MAE на тесте {MAE_test:.2f}', end = '\n\n')

# %% [markdown]
# ### 4.Переобучение и методы борьбы с ним
#
# Если на train set наша модель даёт хорошие предсказания, а на test set нехорошие предсказания,
#
# это значит, что наша модель переобучилась: в этом случае наша модель просто запомнила все предоставленные данные,
#
# а не построила какую-то зависимость.
#
# Надо уметь справляться с такой ситуацией.

# %% [markdown]
# #### Рассмотрим еще одну модель - деревья решений.
#
# Деревья решений являются моделями, широко используемыми для решения задач классификации и регрессии.
#
# По сути они задают вопросы и выстраивают иерархию правил «если… то», приводящую к решению.
#
# Эти вопросы похожи на вопросы, которые вы можете спросить в игре «20 Questions».
#
# Представьте, вам нужно научиться отличать друг от друга четыре вида животных: медведей, ястребов, пингвинов и дельфинов.
#
# Ваша цель состоит в том, чтобы получить правильный ответ, задав несколько вопросов.
#
# Вы могли бы начать с вопроса, есть ли у этих видов животных перья, вопроса, который сужает количество возможных видов животных до двух.
#
# Если получен ответ «да», вы можете задать еще один вопрос, который может помочь вам различать ястребов и пингвинов.
#
# Например, вы могли бы спросить, может ли данный вид животных летать.
#
# Если у этого вида животных нет перьев, ваши возможные варианты – дельфины и медведи, и вам нужно задать вопрос,
#
# чтобы провести различие между этими двумя видами животных, например, спросить, есть ли плавники у этого вида животных.

# %% [markdown]
# ![image.png](attachment:20d3c09f-2bfa-48bd-94f7-16eeca7f6702.png)

# %% [markdown]
# Воспользуемся алгоритмом, реализованным в библиотеке scikit-learn

# %%
# Обучим модель
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(random_state = 44)
model.fit(X_train, y_train)

# Random_state — это параметр, который используется для установки начального состояния генератора случайных чисел в алгоритмах машинного обучения.  
# Этот параметр часто встречается при инициализации весов модели, разделении данных на обучающий и тестовый наборы, 
# случайной инициализации параметров и т. д.
# Цель использования random_state — обеспечить воспроизводимость результатов. 
# Если каждый раз использовать одно и то же значение этого параметра, то при запуске эксперимента будут получаться те же самые случайные числа. 
# Это позволяет повторно воспроизвести эксперимент и проверить результаты моделирования.

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score, mean_absolute_error

pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

MSE_train = mean_squared_error(y_train, pred_train)
RMSE_train = np.sqrt(MSE_train)
R2_train = r2_score(y_train, pred_train)
MAE_train = mean_absolute_error(y_train, pred_train)

MSE_test = mean_squared_error(y_test, pred_test)
RMSE_test = np.sqrt(MSE_test)
R2_test = r2_score(y_test, pred_test)
MAE_test = mean_absolute_error(y_test, pred_test)

print(f'MSE на обучении {MSE_train:.2f}')
print(f'MSE на тесте {MSE_test:.2f}', end = '\n\n')

print(f'RMSE на обучении {RMSE_train:.2f}')
print(f'RMSE на тесте {RMSE_test:.2f}', end = '\n\n')

print(f'R^2 на обучении {R2_train:.2f}')
print(f'R^2 на тесте {R2_test:.2f}', end = '\n\n')

# %% [markdown]
# Мы видим, что на train set наша модель не даёт ошибок!
#
# Но на test set ошибки есть!
#
# Это значит, что наша модель переобучилась!

# %% [markdown]
# ### Методы для борьбы с переобучением:
#
# #### 1.Нужно больше данных.
#
# Один из вариантов увеличения данных - это кросс-валидация.
#
# #### Кросс-валидация реализована в scikit-learn через метод cross_validate.
#
# #### 2.Подбор гиперпараметров в GridSearchCV.
#
# Гиперпараметры - параметры, которые мы сами задаём у модели.
#
# Гиперпараметры можно подбирать (варировать) в ручном режиме. Это может быть долгий процесс.
#
# #### В scikit-learn есть класс GridSearchCV, который даёт нам возможность автоматически перебирать параметры по какой-либо сетке.

# %% [markdown]
# ### 5.Сохранение модели

# %%
# Сохраняем модель на диск
import pickle

filename = 'finalised_model.sav'
pickle.dump(model, open(filename, 'wb'))

# Загружаем модель с диска
loaded_model = pickle.load(open(filename, 'rb'))

# %% [markdown]
# ![image.png](attachment:1782e27e-1b95-4424-bfce-66b0f1190ffd.png)
# # Практика

# %% [markdown]
# ### Задача 1: создайте в какой-либо папке на Вашем компьютере ноутбук в Jupyter Notebook.
#
# Назовите его mynotebook

# %% [markdown]
# ### Задача 2: Создание и выполнение ячеек
#
# Создайте новую ячейку в Jupyter Notebook и напишите в ней код, который выводит на экран фразу "Hello, Jupyter Notebook!". Затем выполните ячейку.

# %%
print("Hello, Jupyter Notebook!")

# %% [markdown]
# ### Задача 3: Работа с заголовками Markdown
#
# Создайте ячейку типа Markdown и напишите в ней заголовок второго уровня с текстом "Основы Jupyter Notebook" (подсказака: используйте ##)

# %% [markdown]
# ## Основы Jupyter Notebook

# %% [markdown]
# ### Задача 4: Использование комментариев в коде
#
# Напишите код с комментариями, который объявляет переменную x = 10 и выводит её значение.

# %%
# Объявляем переменную x
x = 10

# Выводим значение переменной x
print(x)

# %% [markdown]
# ### Задача 5: Арифметические операции
#
# Выполните в Jupyter Notebook простые арифметические операции: сложение, вычитание, умножение и деление двух чисел.
#
# Пример вывода:
#
# Сложение: 10
#
# Вычитание: 6
#
# Умножение: 16
#
# Деление: 4.0

# %%
a = 8
b = 2

print("Сложение:", a + b)
print("Вычитание:", a - b)
print("Умножение:", a * b)
print("Деление:", a / b)

# %% [markdown]
# ### Задача 6: Импорт и использование библиотеки
#
# Импортируйте библиотеку math и найдите:
#
# - квадратный корень из 49;
#
# - абсолютное значение от -49;
#
# - факториал 5.

# %%
import math

print(math.sqrt(49))
print(math.fabs(-49))
print(math.factorial(5))

# %% [markdown]
# ### Задача 7: Построение простого графика с Matplotlib
#
# Используя библиотеку matplotlib, постройте график функции 𝑦 = x² для значений x от -10 до 10.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100)
y = x**2

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("График y = x^2")
plt.grid()
plt.show()

# %% [markdown]
# ### Чего мы достигли:
#
# #### 1.Познакомились с Jupyter Notebook:
#
# #### ●  Как запустить Jupyter Notebook;
#
# #### ●  Как работать с Jupyter Notebook (режимы Code и Markdown);
#
# #### ●  Shortcuts в Jupyter Notebook.
#
# #### 2.Познакомились с функционалом библиотеки sklearn
#
# #### 3.Научились обучать модели для задачи регрессии
#
# #### 4.Научились делать предсказания и оценивать предсказания
#
# #### 5.Научились сохранять модель.

# %% [markdown]
# ### Домашнее задание

# %% [markdown]
# ### Задача 1: создайте в какой-либо папке на Вашем компьютере ноутбук в Jupyter Notebook.
#
# Назовите его myhomework.
#
# Использование функции range() и for-цикла
#
# Напишите код, который выводит все числа от 1 до 5 с помощью цикла for.

# %%
for i in range(1, 6):
    print(i)

# %% [markdown]
# ### Задача 2: Создание списка и обращение к его элементам
#
# Создайте список fruits, содержащий элементы "яблоко", "банан", "груша", и выведите второй элемент списка.

# %%
fruits = ["яблоко", "банан", "груша"]

print(fruits[1])  # Выводит "банан"

# %% [markdown]
# ### Задание 3: Построение простого графика с Matplotlib
#
# Используя библиотеку matplotlib, постройте график функции   𝑦 = 3 - x³   для значений x от -5 до 5.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = 3 - x**3

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("График y = x^3")
plt.grid()
plt.show()
